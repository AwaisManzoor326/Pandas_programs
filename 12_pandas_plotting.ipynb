# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **pandas use the plot() method to plot and draw graphs and diagrams**
#
# We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.

# %%
df = pd.read_csv('data.csv')

df.plot()

plt.show()

# %% [markdown]
# **Scatter plot**
#
# specify that you want a scatter plot with **kind** argument
#
# it requires x-axis and y-axis

# %%
df = pd.read_csv('corr_data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()

# %% [markdown]
# In the previous example, we learned that the correlation between "Duration" and "Calories" was 0.922721, and we concluded with the fact that higher duration means more calories burned.
#
# By looking at the scatterplot, I will agree.

# %%
df.plot(kind='scatter', x='Duration', y='Maxpulse')
plt.show()

# %% [markdown]
# **Histogram**
#
# A histogram needs only one column.
#
# A histogram shows us the frequency of each interval, e.g. how many workouts lasted between 50 and 60 minutes?

# %%
df['Calories'].plot(kind='hist')
plt.show()

# %%
# more on pandas plotting by chatgpt
data = pd.Series([1, 3, 5, 7, 9])
data.plot()
plt.show()

# %%
df = pd.DataFrame({
    "Apples": [3, 2, 0, 1],
    "Oranges": [0, 3, 7, 2]
})

# df.plot()
# df.plot(kind='bar')
df.plot(kind='barh')
plt.show()

# %%
df = pd.DataFrame({
    "Apples": [3, 2, 0, 1],
    "Oranges": [0, 3, 7, 2]
})

# df.plot(kind='area')
df.plot(kind='hist')
plt.show()

# %%
df['Apples'].plot(kind='pie')
# Out:
# <Axes: ylabel='Apples'>

# %% [markdown]
# **we can add axis labels, title and styles**

# %%
df.plot(kind='line', title="fruits Visualization", figsize=(8, 5))
plt.xlabel('Days')
plt.ylabel('Quantity')
plt.grid(True)
plt.show()

# %%
df.plot(kind="scatter", x="Apples", y="Oranges")
plt.show()
